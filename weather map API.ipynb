# %%
! pip install pyowm
# Out:
# ...
#      |████████████████████████████████| 3.1MB 5.1MB/s
# ...

# %%
from pyowm import OWM

# %%
owm = OWM('96caf2ecb140cac271b2ec462e62c33e')
mgr = owm.weather_manager()

# %%
observation = mgr.weather_at_place('Bengaluru, IN')
w = observation.weather

# %%
w.detailed_status
# Out:
# 'scattered clouds'

# %%
w.wind()
# Out:
# {'deg': 0, 'speed': 0}

# %%
w.humidity
# Out:
# 68

# %%
w.temperature('celsius')
# Out:
# {'feels_like': 29.85,
#  'temp': 27.69,
#  'temp_kf': None,
#  'temp_max': 29.01,
#  'temp_min': 25.8}

# %%
w.rain
# Out:
# {}

# %%
w.heat_index

# %%
w.clouds
# Out:
# 40
