# %%
! pip install pyttt

# %%
import ttt
# Out:
# Welcome to T-i-c T-a-c T-o-e
#
# This is a multi player game
#
# Enter 1-Play 2-Quit : 1
#
# Enter Name for user - 1 : nehal
#
# Enter Name for user - 2 : raks
# ---------------------------
# nehal represent's : O
#
# raks represent's : X
# ---------------------------
#
# Please remember the following representation
#
# Representing T-i-c T-a-c T-o-e Matrix
#
# -------------------
# |  1  |  2  |  3  |
# -------------------
# |  4  |  5  |  6  |
# -------------------
# |  7  |  8  |  9  |
# -------------------
#
# You have 9 choice's [1, 2, 3, 4, 5, 6, 7, 8, 9]
#
# nehal please choose a number to place : O
#
# Enter the number : 5
# -------------------
# |     |     |     |
# -------------------
# |     |  O  |     |
# -------------------
# |     |     |     |
# -------------------
# You have 8 choice's [1, 2, 3, 4, 6, 7, 8, 9]
#
# raks please choose a number to place : X
#
# Enter the number : 3
# -------------------
# |     |     |  X  |
# -------------------
# |     |  O  |     |
# ...
